# %%
import pandas as pd
import numpy as np
import database.db as db

# %%
df = pd.read_csv('all_data/gene_name_update/20250801_revised_TFblast2go_topblast_TAIRID_mapping.csv')
df
# Out:
#    Sequences requiring revision           New Sequence name  \
# 0           Xele.ptg000008l.188   Xele.ptg000008l.188_A_NEW
# 1                           NaN   Xele.ptg000008l.188_B_NEW
# 2            Xele.ptg000009l.97    Xele.ptg000009l.97_A_NEW
# 3                           NaN    Xele.ptg000009l.97_B_NEW
# 4          Xele.ptg000012l.1015  Xele.ptg000012l.1015_A_NEW
# 5                           NaN  Xele.ptg000012l.1015_B_NEW
# 6                           NaN  Xele.ptg000012l.1015_C_NEW
# 7          Xele.ptg000018l.1471    Xele.ptg000018l.1471_NEW
# 8          Xele.ptg000018l.1675  Xele.ptg000018l.1675_A_NEW
# 9                           NaN  Xele.ptg000018l.1675_B_NEW
# 10          Xele.ptg000024l.256   Xele.ptg000024l.256_A_NEW
# 11                          NaN   Xele.ptg000024l.256_B_NEW
# 12          Xele.ptg000025l.617   Xele.ptg000025l.617_A_NEW
# 13                          NaN   Xele.ptg000025l.617_B_NEW
# 14           Xele.ptg000028l.94    Xele.ptg000028l.94_A_NEW
# 15                          NaN    Xele.ptg000028l.94_B_NEW
# 16                          NaN    Xele.ptg000028l.94_C_NEW
# 17                          NaN    Xele.ptg000028l.94_D_NEW
# 18          Xele.ptg000031l.163   Xele.ptg000031l.163_A_NEW
# 19                          NaN   Xele.ptg000031l.163_B_NEW
# 20           Xele.ptg000042l.55    Xele.ptg000042l.55_A_NEW
# 21                          NaN    Xele.ptg000042l.55_B_NEW
# 22          Xele.ptg000044l.355   Xele.ptg000044l.355_A_NEW
# 23                          NaN   Xele.ptg000044l.355_B_NEW
# 24           Xele.ptg000044l.38    Xele.ptg000044l.38_A_NEW
# 25                          NaN    Xele.ptg000044l.38_B_NEW
# 26           Xele.ptg000063l.31    Xele.ptg000063l.31_A_NEW
# 27                          NaN    Xele.ptg000063l.31_B_NEW
# 28          Xele.ptg000067l.154   Xele.ptg000067l.154_A_NEW
# 29                          NaN   Xele.ptg000067l.154_B_NEW
# 30                          NaN   Xele.ptg000067l.154_C_NEW
#
#                     All plant best hit Sequence desc. Arabidopsis Locus ID  \
# 0                         Transcription factor bHLH53            AT2G34820
# 1                    Phytoene synthase, chloroplastic            AT5G17230
# 2                   Subtilisin-like serine-protease S            AT5G59810
# 3           Squamosa promoter-binding-like protein 15            AT1G20980
# 4                        Protein root UVB sensitive 6            AT5G49820
# 5                 Probable transcription factor MYB58            AT3G60460
# 6                        B-box zinc finger protein 22            AT1G78600
# 7       Polyadenylation and cleavage factor homolog 4            AT4G04885
# 8   Glyceraldehyde-3-phosphate dehydrogenase 2, cy...            AT1G13440
# 9                  Trihelix transcription factor GT-1            AT1G13450
# 10  5-formyltetrahydrofolate cyclo-ligase-like pro...            AT1G76730
# 11    Ethylene-responsive transcription factor ERF110            AT5G50080
# 12                            Zinc finger protein GIS            AT3G58070
# 13  Alpha/beta hydrolase domain-containing protein...            AT5G20520
# 14  Senescence/dehydration-associated protein At3g...            AT3G51250
# 15                        NADP-dependent malic enzyme            AT2G19900
# 16                        NADP-dependent malic enzyme            AT1G79750
# 17          B3 domain-containing protein Os01g0723500            AT4G33280
# 18      Glycerophosphodiester phosphodiesterase GDPD2            AT5G41080
# 19                   NAC domain-containing protein 83            AT5G13180
# 20                   NAC domain-containing protein 83            AT5G13180
# 21  Pyruvate dehydrogenase E1 component subunit be...            AT5G50850
# 22                       Transcription factor MYB3R-4            AT5G11510
# 23           Rho guanine nucleotide exchange factor 8            AT3G24620
# 24                       MOB kinase activator-like 1A            AT5G45550
# 25               uncharacterized protein LOC105038636            AT5G16100
# 26              Beta-glucuronosyltransferase GlcAT14A            AT5G39990
# 27                       GATA transcription factor 20            AT1G51600
# 28                     Protein indeterminate-domain 7            AT1G55110
# 29        Probable phospholipid-transporting ATPase 4            AT1G17500
# 30                                    Glutaredoxin-C7            AT4G33040
#
#    Arabidopsis Gene name                 Arabidopsis orthologue description
# 0              AT2G34820  basic helix-loop-helix (bHLH) DNA-binding supe...
# 1                    PSY                                  PHYTOENE SYNTHASE
# 2                 SBT5.4                           Subtilase family protein
# 3                  SPL14          squamosa promoter binding protein-like 14
# 4                   RUS6  root UVB sensitive protein (Protein of unknown...
# 5                   DUO1  myb-like HTH transcriptional regulator family ...
# 6                   LZF1              light-regulated zinc finger protein 1
# 7                  PCFS4                           PCF11P-similar protein 4
# 8                  GAPC2        glyceraldehyde-3-phosphate dehydrogenase C2
# 9                   GT-1               Homeodomain-like superfamily protein
# 10               COG0212  NagB/RpiA/CoA transferase-like superfamily pro...
# 11                ERF110                       ethylene response factor 110
# 12                   GIS     C2H2 and C2HC zinc fingers superfamily protein
# 13                  WAV2          alpha/beta-Hydrolases superfamily protein
# 14             AT3G51250  Senescence/dehydration-associated protein-like...
# 15              NADP-ME1                                NADP-malic enzyme 1
# 16              NADP-ME4                                NADP-malic enzyme 4
# 17             AT4G33280  AP2/B3-like transcriptional factor family protein
# 18                 GDPD2    PLC-like phosphodiesterases superfamily protein
# 19                NAC083                   NAC domain containing protein 83
# 20                NAC083                   NAC domain containing protein 83
# 21                  MAB1                       Transketolase family protein
# 22               MYB3R-4                            myb domain protein 3r-4
# 23               ROPGEF8            RHO guanyl-nucleotide exchange factor 8
# 24             MOB1-like                        Mob1/phocein family protein
# 25             AT5G16100                              RWP-RK domain protein
# 26             AT5G39990  Core-2/I-branching beta-1,6-N-acetylglucosamin...
# 27                  ZML2                                         ZIM-LIKE 2
# 28                  IDD7                         indeterminate(ID)-domain 7
# 29             AT1G17500  ATPase E1-E2 type family protein / haloacid de...
# 30             AT4G33040                    Thioredoxin superfamily protein

# %%
genes_to_delete = df['Sequences requiring revision'].dropna().tolist()
print(genes_to_delete)
print(f"Total genes to delete: {len(genes_to_delete)}")
# Out:
# ['Xele.ptg000008l.188', 'Xele.ptg000009l.97', 'Xele.ptg000012l.1015', 'Xele.ptg000018l.1471', 'Xele.ptg000018l.1675', 'Xele.ptg000024l.256', 'Xele.ptg000025l.617', 'Xele.ptg000028l.94', 'Xele.ptg000031l.163', 'Xele.ptg000042l.55', 'Xele.ptg000044l.355', 'Xele.ptg000044l.38', 'Xele.ptg000063l.31', 'Xele.ptg000067l.154']
# Total genes to delete: 14

# %%
db = db.DB()

results = db.delete_genes_by_names(genes_to_delete, dry_run=False, cleanup_orphans=False)
# Out:
# Attempting to delete 14 genes...
# Found gene: Xele.ptg000008l.188 (ID: 20107)
# Found gene: Xele.ptg000009l.97 (ID: 18203)
# Found gene: Xele.ptg000012l.1015 (ID: 14350)
# Found gene: Xele.ptg000018l.1471 (ID: 11568)
# Found gene: Xele.ptg000018l.1675 (ID: 11766)
# Found gene: Xele.ptg000024l.256 (ID: 27294)
# Found gene: Xele.ptg000025l.617 (ID: 15087)
# Found gene: Xele.ptg000028l.94 (ID: 1531)
# Found gene: Xele.ptg000031l.163 (ID: 7252)
# Found gene: Xele.ptg000042l.55 (ID: 9687)
# Found gene: Xele.ptg000044l.355 (ID: 9232)
# Found gene: Xele.ptg000044l.38 (ID: 8929)
# Found gene: Xele.ptg000063l.31 (ID: 27682)
# Found gene: Xele.ptg000067l.154 (ID: 6520)
# Gene Xele.ptg000008l.188: 1 annotations, 42 expressions, 1 diff expressions, 2623 interactions, 1 homologue associations
# Gene Xele.ptg000009l.97: 1 annotations, 42 expressions, 1 diff expressions, 222 interactions, 1 homologue associations
# Gene Xele.ptg000012l.1015: 1 annotations, 42 expressions, 1 diff expressions, 3126 interactions, 1 homologue associations
# Gene Xele.ptg000018l.1471: 1 annotations, 42 expressions, 1 diff expressions, 2414 interactions, 1 homologue associations
# Gene Xele.ptg000018l.1675: 1 annotations, 42 expressions, 1 diff expressions, 5092 interactions, 1 homologue associations
# Gene Xele.ptg000024l.256: 1 annotations, 42 expressions, 1 diff expressions, 2371 interactions, 1 homologue associations
# Gene Xele.ptg000025l.617: 1 annotations, 42 expressions, 1 diff expressions, 2215 interactions, 1 homologue associations
# Gene Xele.ptg000028l.94: 1 annotations, 42 expressions, 1 diff expressions, 1531 interactions, 1 homologue associations
# Gene Xele.ptg000031l.163: 1 annotations, 42 expressions, 1 diff expressions, 1256 interactions, 1 homologue associations
# Gene Xele.ptg000042l.55: 1 annotations, 42 expressions, 1 diff expressions, 4216 interactions, 1 homologue associations
# Gene Xele.ptg000044l.355: 1 annotations, 42 expressions, 1 diff expressions, 4696 interactions, 1 homologue associations
# Gene Xele.ptg000044l.38: 1 annotations, 42 expressions, 1 diff expressions, 109 interactions, 1 homologue associations
# Gene Xele.ptg000063l.31: 1 annotations, 42 expressions, 1 diff expressions, 2396 interactions, 1 homologue associations
# Gene Xele.ptg000067l.154: 1 annotations, 42 expressions, 1 diff expressions, 2215 interactions, 1 homologue associations
# Proceeding with deletion...
# Deleted gene: Xele.ptg000008l.188
# Deleted gene: Xele.ptg000009l.97
# Deleted gene: Xele.ptg000012l.1015
# Deleted gene: Xele.ptg000018l.1471
# Deleted gene: Xele.ptg000018l.1675
# Deleted gene: Xele.ptg000024l.256
# Deleted gene: Xele.ptg000025l.617
# Deleted gene: Xele.ptg000028l.94
# Deleted gene: Xele.ptg000031l.163
# Deleted gene: Xele.ptg000042l.55
# Deleted gene: Xele.ptg000044l.355
# Deleted gene: Xele.ptg000044l.38
# Deleted gene: Xele.ptg000063l.31
# Deleted gene: Xele.ptg000067l.154
# Successfully deleted 14 genes and all associated data

# %%
results = db.delete_genes_by_names(genes_to_delete, dry_run=True, cleanup_orphans=False)
# Out:
# DRY RUN: Attempting to delete 14 genes...
# Gene not found: Xele.ptg000008l.188
# Gene not found: Xele.ptg000009l.97
# Gene not found: Xele.ptg000012l.1015
# Gene not found: Xele.ptg000018l.1471
# Gene not found: Xele.ptg000018l.1675
# Gene not found: Xele.ptg000024l.256
# Gene not found: Xele.ptg000025l.617
# Gene not found: Xele.ptg000028l.94
# Gene not found: Xele.ptg000031l.163
# Gene not found: Xele.ptg000042l.55
# Gene not found: Xele.ptg000044l.355
# Gene not found: Xele.ptg000044l.38
# Gene not found: Xele.ptg000063l.31
# Gene not found: Xele.ptg000067l.154
# No genes found to delete.
